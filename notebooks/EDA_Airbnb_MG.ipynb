# %%
#charger les tables

import pandas as pd

df_listings = pd.read_csv("listings_paris.csv")
df_reviews = pd.read_csv("reviews.csv")
df_neighbourhoods = pd.read_csv("neighbourhoods_paris.csv")

# %%
import pandas as pd

# %%
# !wget https://data.insideairbnb.com/france/ile-de-france/paris/2025-09-12/data/calendar.csv.gz
# Out:
# --2026-04-13 09:25:30--  https://data.insideairbnb.com/france/ile-de-france/paris/2025-09-12/data/calendar.csv.gz
# Resolving data.insideairbnb.com (data.insideairbnb.com)... 143.204.204.62, 143.204.204.129, 143.204.204.13, ...
# Connecting to data.insideairbnb.com (data.insideairbnb.com)|143.204.204.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72087684 (69M) [application/x-gzip]
# Saving to: ‘calendar.csv.gz’
#
# calendar.csv.gz     100%[===================>]  68.75M  35.4MB/s    in 1.9s
#
# 2026-04-13 09:25:32 (35.4 MB/s) - ‘calendar.csv.gz’ saved [72087684/72087684]

# %%
df_calendar = pd.read_csv("/content/calendar.csv.gz")
#EOFError: Compressed file ended before the end-of-stream marker was reached

# %%
df_calendar.head()
# Out:
#    listing_id        date available  price  adjusted_price  minimum_nights  \
# 0     2719440  2025-09-12         f    NaN             NaN               2
# 1     2719440  2025-09-13         f    NaN             NaN               2
# 2     2719440  2025-09-14         f    NaN             NaN               2
# 3     2719440  2025-09-15         f    NaN             NaN               2
# 4     2719440  2025-09-16         f    NaN             NaN               2
#
#    maximum_nights
# 0               7
# 1               7
# 2               7
# 3               7
# 4               7

# %%
#Visualiser Listings > Détail de chaque annonce (prix, type, localisation…)
df_listings.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0  2719440  https://www.airbnb.com/rooms/2719440  20250912034503   2025-09-12
# 1  2721397  https://www.airbnb.com/rooms/2721397  20250912034503   2025-09-12
# 2  2726092  https://www.airbnb.com/rooms/2726092  20250912034503   2025-09-12
# 3  2726327  https://www.airbnb.com/rooms/2726327  20250912034503   2025-09-12
# 4  2727929  https://www.airbnb.com/rooms/2727929  20250912034503   2025-09-12
#
#             source                                            name  \
# 0  previous scrape                 Nice flat close to Montparnasse
# 1  previous scrape              Marais - Charming loft, river view
# 2  previous scrape               Superbe 2 pièces idéalement placé
# 3  previous scrape  Cozy place, Sacré Coeur Montmartre in the SoPi
# 4  previous scrape           Appartement d'architecte - Montmartre
#
#                                          description  \
# ...

# %%
#df_calendar.head()
#Disponibilités et prix par date
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_31250/2326408327.py in <cell line: 0>()
# ----> 1 df_calendar = pd.read_csv("calendar_paris.csv.gz")
#       2 df_calendar.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#Visualiser reviews : Avis des voyageurs
df_reviews.head()
# Out:
#    listing_id        date
# 0        3109  2017-10-28
# 1        3109  2017-11-03
# 2        3109  2018-07-24
# 3        3109  2019-10-24
# 4        3109  2025-04-08

# %%
#Visualiser neighbourhood : Contours géographiques des quartiers
df_neighbourhoods.head()
# Out:
#    neighbourhood_group        neighbourhood
# 0                  NaN  Batignolles-Monceau
# 1                  NaN               Bourse
# 2                  NaN      Buttes-Chaumont
# 3                  NaN    Buttes-Montmartre
# 4                  NaN               Élysée

# %%
#df.info()
#df.describe()
#df.isnull().sum()
